# %%
import pandas as pd

# %%
scroll_features = pd.read_pickle('./scroll_features.pkl')

# %%
scroll_features.head(20)
# Out:
#                                            text read_value  time_values  \
# 0                        WNL Can the US-ele.txt       read        92909
# 1                       Swedish prisons-ele.txt       read       926925
# 2       WNL 101 year old bottle message-ele.txt       read       275667
# 3                       WNL Will drones-ele.txt       read       135786
# 4       WNL 101 year old bottle message-ele.txt       read       208804
# 5                       WNL Will drones-ele.txt       read       193481
# 6                   WNL Swarthy caveman-ele.txt       read        91975
# 7                            WNL Rwanda-ele.txt       read       292486
# 8                    WNL Wealth therapy-ele.txt       read       105300
# 9                         WNL Man falls-ele.txt       read       134492
# 10  WNL Why you should start work at 10-ele.txt       read        92099
# 11  WNL Why you should start work at 10-ele.txt       read       164266
# ...
